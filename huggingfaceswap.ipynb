# %%
# !git lfs install
# !git clone https://huggingface.co/spaces/victorisgeek/DeepSwapFace
# %cd /kaggle/working/DeepSwapFace
# !mv /kaggle/input/config/config_colab.yaml config.yaml
# !pip install pip install -r requirements.txt

# %%
default_output_path = "/kaggle/working/DeepSwapFace" #@param {type:"string"}

command = f"python app.py --cuda --colab --out_dir {default_output_path}"
# !{command}
